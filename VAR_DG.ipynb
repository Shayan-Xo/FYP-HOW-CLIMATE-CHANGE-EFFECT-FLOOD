# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from sklearn.preprocessing import LabelEncoder
from statsmodels.tsa.stattools import grangercausalitytests

data = pd.read_csv('/content/drive/MyDrive/FYP Data/Main/Dera Ghazi Khan CSV.csv')
data = data.drop(['Year', 'Month'], axis=1)

data
# Out:
#         M_Date  Maximum Temperature  Minimum Temperature  Precipitation  \
# 0     1/1/1958                22.95                 7.13            5.8
# 1     2/1/1958                24.60                 8.79            1.6
# 2     3/1/1958                31.00                14.77            1.4
# 3     4/1/1958                38.57                22.08            0.3
# 4     5/1/1958                40.25                23.32            1.4
# ..         ...                  ...                  ...            ...
# 773   6/1/2022                34.40                18.00          110.0
# 774   7/1/2022                32.70                14.80          184.0
# 775   8/1/2022                30.60                13.10          155.0
# 776   9/1/2022                31.20                16.20            2.0
# 777  10/1/2022                26.80                15.10            0.0
#
#      Soil Moisture  Wind Speed  Runoff  Flood
# 0              1.8        0.81     0.3  False
# 1              1.8        1.41     0.1  False
# 2              1.7        1.81     0.1  False
# 3              1.6        2.10     0.0  False
# 4              1.6        2.65     0.1  False
# ..             ...         ...     ...    ...
# 773            0.1        2.00     0.9   True
# 774            0.2        1.20     4.7   True
# 775            0.2        0.90     2.9   True
# 776            0.1        0.60     2.1  False
# 777            0.1        1.00     0.0  False
#
# [778 rows x 8 columns]

# %%
data.index = pd.to_datetime(data['M_Date'], format='%m/%d/%Y')
data = data.drop(['M_Date'], axis=1)

le = LabelEncoder()
data['Flood'] = le.fit_transform(data.Flood.values)

data
# Out:
#             Maximum Temperature  Minimum Temperature  Precipitation  \
# M_Date
# 1958-01-01                22.95                 7.13            5.8
# 1958-02-01                24.60                 8.79            1.6
# 1958-03-01                31.00                14.77            1.4
# 1958-04-01                38.57                22.08            0.3
# 1958-05-01                40.25                23.32            1.4
# ...                         ...                  ...            ...
# 2022-06-01                34.40                18.00          110.0
# 2022-07-01                32.70                14.80          184.0
# 2022-08-01                30.60                13.10          155.0
# 2022-09-01                31.20                16.20            2.0
# 2022-10-01                26.80                15.10            0.0
#
#             Soil Moisture  Wind Speed  Runoff  Flood
# M_Date
# 1958-01-01            1.8        0.81     0.3      0
# 1958-02-01            1.8        1.41     0.1      0
# 1958-03-01            1.7        1.81     0.1      0
# 1958-04-01            1.6        2.10     0.0      0
# 1958-05-01            1.6        2.65     0.1      0
# ...                   ...         ...     ...    ...
# 2022-06-01            0.1        2.00     0.9      1
# 2022-07-01            0.2        1.20     4.7      1
# 2022-08-01            0.2        0.90     2.9      1
# 2022-09-01            0.1        0.60     2.1      0
# 2022-10-01            0.1        1.00     0.0      0
#
# [778 rows x 7 columns]

# %%
maxlag=12

test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

grangers_causation_matrix(data, variables = data.columns)
# Out:
#                        Maximum Temperature_x  Minimum Temperature_x  \
# Maximum Temperature_y                 1.0000                 0.0000
# Minimum Temperature_y                 0.0000                 1.0000
# Precipitation_y                       0.0000                 0.0000
# Soil Moisture_y                       0.1620                 0.0761
# Wind Speed_y                          0.0000                 0.0000
# Runoff_y                              0.0000                 0.0000
# Flood_y                               0.0001                 0.0114
#
#                        Precipitation_x  Soil Moisture_x  Wind Speed_x  \
# Maximum Temperature_y           0.0000           0.0617        0.0000
# Minimum Temperature_y           0.0000           0.0861        0.0000
# Precipitation_y                 1.0000           0.0003        0.0000
# Soil Moisture_y                 0.0115           1.0000        0.0558
# Wind Speed_y                    0.0000           0.0064        1.0000
# Runoff_y                        0.0019           0.0009        0.0000
# Flood_y                         0.0001           0.4428        0.0028
#
#                        Runoff_x  Flood_x
# Maximum Temperature_y    0.0000   0.0000
# Minimum Temperature_y    0.0000   0.0138
# Precipitation_y          0.0000   0.0000
# Soil Moisture_y          0.0072   0.0000
# Wind Speed_y             0.0000   0.0018
# Runoff_y                 1.0000   0.0000
# Flood_y                  0.0020   1.0000

# %%
from statsmodels.tsa.vector_ar.vecm import coint_johansen

def cointegration_test(data, alpha=0.05): 
    out = coint_johansen(data,-1,5)
    d = {'0.90':0, '0.95':1, '0.99':2}
    traces = out.lr1
    cvts = out.cvt[:, d[str(1-alpha)]]
    def adjust(val, length= 6): return str(val).ljust(length)

    print('Name   ::  Test Stat > C(95%)    =>   Signif  \n', '--'*20)
    for col, trace, cvt in zip(data.columns, traces, cvts):
        print(adjust(col), ':: ', adjust(round(trace,2), 9), ">", adjust(cvt, 8), ' =>  ' , trace > cvt)

cointegration_test(data)
# Out:
# Name   ::  Test Stat > C(95%)    =>   Signif
#  ----------------------------------------
# Maximum Temperature ::  924.98    > 111.7797  =>   True
# Minimum Temperature ::  524.95    > 83.9383   =>   True
# Precipitation ::  296.33    > 60.0627   =>   True
# Soil Moisture ::  157.96    > 40.1749   =>   True
# Wind Speed ::  47.07     > 24.2761   =>   True
# Runoff ::  12.52     > 12.3212   =>   True
# Flood  ::  0.33      > 4.1296    =>   False

# %%
nobs = 150
df_train, df_test = data[0:-nobs], data[-nobs:]

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

for name, column in df_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Maximum Temperature"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.2208
#  No. Lags Chosen       = 18
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Minimum Temperature"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.0595
#  No. Lags Chosen       = 15
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Precipitation"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.9646
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Soil Moisture"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.285
#  No. Lags Chosen       = 19
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0005. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Wind Speed"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.3834
#  No. Lags Chosen       = 17
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0115. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Runoff"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.9852
#  No. Lags Chosen       = 13
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Flood"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.1
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.441
#  Critical value 5%     = -2.866
#  Critical value 10%    = -2.569
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
df_train
# Out:
#             Maximum Temperature  Minimum Temperature  Precipitation  \
# M_Date
# 1958-01-01                22.95                 7.13            5.8
# 1958-02-01                24.60                 8.79            1.6
# 1958-03-01                31.00                14.77            1.4
# 1958-04-01                38.57                22.08            0.3
# 1958-05-01                40.25                23.32            1.4
# ...                         ...                  ...            ...
# 2009-12-01                23.27                 5.57            2.6
# 2010-01-01                20.88                 4.82            2.6
# 2010-02-01                24.41                 9.20            1.2
# 2010-03-01                32.69                16.95           12.9
# 2010-04-01                38.65                22.24            3.8
#
#             Soil Moisture  Wind Speed  Runoff  Flood
# M_Date
# 1958-01-01            1.8        0.81     0.3      0
# 1958-02-01            1.8        1.41     0.1      0
# 1958-03-01            1.7        1.81     0.1      0
# 1958-04-01            1.6        2.10     0.0      0
# 1958-05-01            1.6        2.65     0.1      0
# ...                   ...         ...     ...    ...
# 2009-12-01            0.1        0.42     0.1      0
# 2010-01-01            0.1        0.53     0.1      0
# 2010-02-01            0.1        1.26     0.1      0
# 2010-03-01            0.1        1.07     0.6      0
# 2010-04-01            0.1        1.49     0.2      0
#
# [628 rows x 7 columns]

# %%
model = VAR(df_train)

x = model.select_order(maxlags=12)
x.summary()
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/base/tsa_model.py:524: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   warnings.warn('No frequency information was'
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model_fitted = model.fit(6)
model_fitted.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Wed, 04, Jan, 2023
# Time:                     03:32:46
# --------------------------------------------------------------------
# No. of Equations:         7.00000    BIC:                   -13.7948
# Nobs:                     622.000    HQIC:                  -15.1063
# Log likelihood:          -919.714    FPE:                1.19677e-07
# AIC:                     -15.9400    Det(Omega_mle):     7.49537e-08
# --------------------------------------------------------------------
# Results for equation Maximum Temperature
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                         27.052114         2.602281           10.396           0.000
# L1.Maximum Temperature         0.267743         0.059289            4.516           0.000
# L1.Minimum Temperature         0.260454         0.060299            4.319           0.000
# L1.Precipitation              -0.020978         0.109421           -0.192           0.848
# L1.Soil Moisture               3.034576         4.460885            0.680           0.496
# L1.Wind Speed                  0.100584         0.205817            0.489           0.625
# L1.Runoff                      0.580220         2.188469            0.265           0.791
# L1.Flood                      -0.487009         0.494288           -0.985           0.324
# L2.Maximum Temperature        -0.248236         0.061362           -4.045           0.000
# L2.Minimum Temperature         0.232398         0.068852            3.375           0.001
# L2.Precipitation              -0.039894         0.109608           -0.364           0.716
# L2.Soil Moisture              -1.218227         5.546007           -0.220           0.826
# L2.Wind Speed                 -0.120062         0.219072           -0.548           0.584
# L2.Runoff                      0.939541         2.192954            0.428           0.668
# L2.Flood                      -0.462404         0.503281           -0.919           0.358
# L3.Maximum Temperature        -0.188144         0.060890           -3.090           0.002
# L3.Minimum Temperature         0.052692         0.068975            0.764           0.445
# L3.Precipitation               0.154607         0.109604            1.411           0.158
# L3.Soil Moisture               0.526908         5.455081            0.097           0.923
# L3.Wind Speed                  0.322853         0.220558            1.464           0.143
# L3.Runoff                     -3.007171         2.193466           -1.371           0.170
# L3.Flood                       0.849721         0.512973            1.656           0.098
# L4.Maximum Temperature         0.145474         0.059160            2.459           0.014
# L4.Minimum Temperature        -0.248607         0.068874           -3.610           0.000
# L4.Precipitation               0.051836         0.109858            0.472           0.637
# L4.Soil Moisture              -9.991613         5.439883           -1.837           0.066
# L4.Wind Speed                  0.237735         0.220025            1.080           0.280
# L4.Runoff                     -1.308634         2.198637           -0.595           0.552
# L4.Flood                      -0.199074         0.516380           -0.386           0.700
# L5.Maximum Temperature         0.169894         0.060245            2.820           0.005
# L5.Minimum Temperature        -0.329495         0.069576           -4.736           0.000
# L5.Precipitation              -0.176007         0.110249           -1.596           0.110
# L5.Soil Moisture              16.048034         5.302594            3.026           0.002
# L5.Wind Speed                 -0.239113         0.217147           -1.101           0.271
# L5.Runoff                      3.426054         2.207310            1.552           0.121
# L5.Flood                       0.516114         0.508535            1.015           0.310
# L6.Maximum Temperature         0.149996         0.057613            2.603           0.009
# L6.Minimum Temperature        -0.185912         0.065798           -2.825           0.005
# L6.Precipitation              -0.105702         0.110647           -0.955           0.339
# L6.Soil Moisture              -8.105440         4.144493           -1.956           0.050
# L6.Wind Speed                 -0.544470         0.206766           -2.633           0.008
# L6.Runoff                      2.093022         2.214274            0.945           0.345
# L6.Flood                      -0.185809         0.488949           -0.380           0.704
# =========================================================================================
#
# Results for equation Minimum Temperature
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                
# L4.Wind Speed                 -0.063066         0.121643           -0.518           0.604
# L4.Runoff                     -1.182252         1.215540           -0.973           0.331
# L4.Flood                       0.288601         0.285486            1.011           0.312
# L5.Maximum Temperature        -0.046027         0.033307           -1.382           0.167
# L5.Minimum Temperature         0.054712         0.038466            1.422           0.155
# L5.Precipitation               0.062291         0.060952            1.022           0.307
# L5.Soil Moisture              -2.520145         2.931596           -0.860           0.390
# L5.Wind Speed                 -0.287034         0.120052           -2.391           0.017
# L5.Runoff                     -1.329590         1.220335           -1.090           0.276
# L5.Flood                      -0.268067         0.281149           -0.953           0.340
# L6.Maximum Temperature        -0.123829         0.031852           -3.888           0.000
# L6.Minimum Temperature         0.082021         0.036377            2.255           0.024
# L6.Precipitation              -0.054456         0.061172           -0.890           0.373
# L6.Soil Moisture               0.819723         2.291327            0.358           0.721
# L6.Wind Speed                  0.214120         0.114313            1.873           0.061
# L6.Runoff                      1.033784         1.224185            0.844           0.398
# L6.Flood                      -0.057280         0.270321           -0.212           0.832
# =========================================================================================
#
# Results for equation Flood
# =========================================================================================
#                             coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------
# const                          0.255270         0.221653            1.152           0.249
# L1.Maximum Temperature        -0.004226         0.005050           -0.837           0.403
# L1.Minimum Temperature         0.003381         0.005136            0.658           0.510
# L1.Precipitation              -0.005276         0.009320           -0.566           0.571
# L1.Soil Moisture              -0.849269         0.379961           -2.235           0.025
# L1.Wind Speed                  0.027291         0.017531            1.557           0.120
# L1.Runoff                      0.118394         0.186406            0.635           0.525
# L1.Flood                       0.197090         0.042102            4.681           0.000
# L2.Maximum Temperature         0.000773         0.005227            0.148           0.882
# L2.Minimum Temperature         0.002106         0.005865            0.359           0.719
# L2.Precipitation               0.021596         0.009336            2.313           0.021
# L2.Soil Moisture               0.948239         0.472388            2.007           0.045
# L2.Wind Speed                  0.005325         0.018660            0.285           0.775
# L2.Runoff                     -0.430472         0.186788           -2.305           0.021
# L2.Flood                       0.127640         0.042868            2.978           0.003
# L3.Maximum Temperature        -0.004888         0.005186           -0.942           0.346
# L3.Minimum Temperature         0.003360         0.005875            0.572           0.567
# L3.Precipitation               0.002214         0.009336            0.237           0.813
# L3.Soil Moisture              -0.038310         0.464643           -0.082           0.934
# L3.Wind Speed                  0.017176         0.018786            0.914           0.361
# L3.Runoff                     -0.049249         0.186831           -0.264           0.792
# L3.Flood                      -0.063889         0.043693           -1.462           0.144
# L4.Maximum Temperature         0.002215         0.005039            0.440           0.660
# L4.Minimum Temperature        -0.000936         0.005866           -0.160           0.873
# L4.Precipitation               0.011149         0.009357            1.191           0.233
# L4.Soil Moisture              -0.073971         0.463349           -0.160           0.873
# L4.Wind Speed                 -0.006998         0.018741           -0.373           0.709
# L4.Runoff                     -0.221976         0.187272           -1.185           0.236
# L4.Flood                      -0.004833         0.043983           -0.110           0.912
# L5.Maximum Temperature        -0.008193         0.005131           -1.597           0.110
# L5.Minimum Temperature         0.004797         0.005926            0.809           0.418
# L5.Precipitation               0.009196         0.009391            0.979           0.327
# L5.Soil Moisture              -0.763192         0.451655           -1.690           0.091
# L5.Wind Speed                 -0.021610         0.018496           -1.168           0.243
# L5.Runoff                     -0.190533         0.188010           -1.013           0.311
# L5.Flood                       0.010573         0.043315            0.244           0.807
# L6.Maximum Temperature        -0.005383         0.004907           -1.097           0.273
# L6.Minimum Temperature         0.008095         0.005604            1.444           0.149
# L6.Precipitation              -0.008827         0.009425           -0.937           0.349
# L6.Soil Moisture               0.733180         0.353012            2.077           0.038
# L6.Wind Speed                  0.007572         0.017612            0.430           0.667
# L6.Runoff                      0.174378         0.188604            0.925           0.355
# L6.Flood                       0.004536         0.041647            0.109           0.913
# =========================================================================================
#
# Correlation matrix of residuals
#                        Maximum Temperature  Minimum Temperature  Precipitation  Soil Moisture  Wind Speed    Runoff     Flood
# Maximum Temperature               1.000000             0.683660      -0.354248      -0.016512    0.127246 -0.356083 -0.067654
# Minimum Temperature               0.683660             1.000000      -0.130741       0.022851    0.056908 -0.131919 -0.055554
# Precipitation                    -0.354248            -0.130741       1.000000       0.042955   -0.210907  0.999406  0.182873
# Soil Moisture                    -0.016512             0.022851       0.042955       1.000000   -0.021470  0.042301 -0.006737
# Wind Speed                        0.127246             0.056908      -0.210907      -0.021470    1.000000 -0.207891 -0.031009
# Runoff                           -0.356083            -0.131919       0.999406       0.042301   -0.207891  1.000000  0.183396
# Flood                            -0.067654            -0.055554       0.182873      -0.006737   -0.031009  0.183396  1.000000

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(model_fitted.resid)

for col, val in zip(data.columns, out):
    print((col), ':', round(val, 2))
# Out:
# Maximum Temperature : 2.02
# Minimum Temperature : 2.11
# Precipitation : 2.03
# Soil Moisture : 1.99
# Wind Speed : 2.01
# Runoff : 2.03
# Flood : 2.0

# %%
lag_order = model_fitted.k_ar
print(lag_order)

forecast_input = df_train.values[-lag_order:]
forecast_input
# Out:
# 6
# array([[27.94,  9.83,  0.  ,  0.1 ,  0.56,  0.  ,  0.  ],
#        [23.27,  5.57,  2.6 ,  0.1 ,  0.42,  0.1 ,  0.  ],
#        [20.88,  4.82,  2.6 ,  0.1 ,  0.53,  0.1 ,  0.  ],
#        [24.41,  9.2 ,  1.2 ,  0.1 ,  1.26,  0.1 ,  0.  ],
#        [32.69, 16.95, 12.9 ,  0.1 ,  1.07,  0.6 ,  0.  ],
#        [38.65, 22.24,  3.8 ,  0.1 ,  1.49,  0.2 ,  0.  ]])

# %%
fc = model_fitted.forecast(y=forecast_input, steps=nobs)
df_forecast = pd.DataFrame(fc, index=data.index[-nobs:], columns=data.columns + '_2d')
df_forecast
# Out:
#             Maximum Temperature_2d  Minimum Temperature_2d  Precipitation_2d  \
# M_Date
# 2010-05-01               41.267502               25.838463         16.510871
# 2010-06-01               41.231044               27.871749         26.682653
# 2010-07-01               39.276425               27.941333         38.019433
# 2010-08-01               37.015679               25.670226         40.926531
# 2010-09-01               34.998399               21.114320         18.057010
# ...                            ...                     ...               ...
# 2022-06-01               39.294024               25.769659         24.663235
# 2022-07-01               38.700276               25.242200         25.354640
# 2022-08-01               36.512104               22.624293         23.087669
# 2022-09-01               33.290045               18.608837         18.626289
# 2022-10-01               29.870513               14.275736         13.353988
#
#             Soil Moisture_2d  Wind Speed_2d  Runoff_2d  Flood_2d
# M_Date
# 2010-05-01          0.098430       1.760385   0.825699  0.035127
# 2010-06-01          0.096295       1.708170   1.339366  0.016802
# 2010-07-01          0.099175       1.408654   1.896452  0.045297
# 2010-08-01          0.096958       0.986333   2.043201  0.064940
# 2010-09-01          0.098188       0.753984   0.902128  0.040055
# ...                      ...            ...        ...       ...
# 2022-06-01          0.135863       1.839237   1.231582  0.033351
# 2022-07-01          0.135880       1.658710   1.265672  0.039855
# 2022-08-01          0.135910       1.415804   1.151698  0.039979
# 2022-09-01          0.135977       1.175757   0.928039  0.033761
# 2022-10-01          0.136093       1.002140   0.664030  0.023216
#
# [150 rows x 7 columns]

# %%
from statsmodels.tsa.stattools import acf
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'corr':corr, 'minmax':minmax})

print('Forecast Accuracy of: Maximum Temperature')
accuracy_prod = forecast_accuracy(df_forecast['Maximum Temperature_2d'].values, df_test['Maximum Temperature'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))

print('\nForecast Accuracy of: Minimum Temperature')
accuracy_prod = forecast_accuracy(df_forecast['Minimum Temperature_2d'].values, df_test['Minimum Temperature'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))

print('\nForecast Accuracy of: Precipitation')
accuracy_prod = forecast_accuracy(df_forecast['Precipitation_2d'].values, df_test['Precipitation'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))

print('\nForecast Accuracy of: Soil Moisture')
accuracy_prod = forecast_accuracy(df_forecast['Soil Moisture_2d'].values, df_test['Soil Moisture'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))

print('\nForecast Accuracy of: Wind Speed')
accuracy_prod = forecast_accuracy(df_forecast['Wind Speed_2d'].values, df_test['Wind Speed'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))

print('\nForecast Accuracy of: Runoff')
accuracy_prod = forecast_accuracy(df_forecast['Runoff_2d'].values, df_test['Runoff'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))

print('\nForecast Accuracy of: Flood')
accuracy_prod = forecast_accuracy(df_forecast['Flood_2d'].values, df_test['Flood'])
for k, v in accuracy_prod.items():
    print((k), ': ', round(v,4))
# Out:
# Forecast Accuracy of: Maximum Temperature
# mape :  0.0925
# me :  0.5077
# mae :  2.5364
# mpe :  0.0342
# rmse :  3.3105
# corr :  0.8787
# minmax :  0.0803
#
# Forecast Accuracy of: Minimum Temperature
# mape :  0.219
# me :  0.3628
# mae :  2.5295
# mpe :  0.111
# rmse :  3.1561
# corr :  0.9193
# minmax :  0.1636
#
# Forecast Accuracy of: Precipitation
# mape :  inf
# me :  -3.9872
# mae :  15.2042
# mpe :  inf
# rmse :  30.0521
# corr :  0.498
# minmax :  0.7261
#
# Forecast Accuracy of: Soil Moisture
# mape :  0.8077
# me :  -1.6686
# mae :  1.6719
# mpe :  -0.7742
# rmse :  2.9033
# corr :  -0.2341
# minmax :  0.8033
#
# Forecast Accuracy of: Wind Speed
# mape :  inf
# me :  0.2054
# mae :  0.2631
# mpe :  inf
# rmse :  0.323
# corr :  0.8402
# minmax :  0.2016
#
# Forecast Accuracy of: Runoff
# mape :  inf
# me :  -0.1211
# mae :  0.6602
# mpe :  nan
# rmse :  1.232
# corr :  0.5325
# minmax :  inf
#
# Forecast Accuracy of: Flood
# mape :  inf
# me :  -0.0236
# mae :  0.058
# mpe :  nan
# rmse :  0.1966
# corr :  0.0888
# minmax :  inf
# <ipython-input-29-cd7d5be65065>:10: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
# <ipython-input-29-cd7d5be65065>:12: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   actual[:,None]]), axis=1)
# <ipython-input-29-cd7d5be65065>:13: RuntimeWarning: divide by zero encountered in true_divide
#   minmax = 1 - np.mean(mins/maxs)             # minmax
